# %%
import csv
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Stock Processing

# %%
def load_csv(csv_path):
    with open(csv_path, 'r', newline='') as csv_fh:
        headers = csv_fh.readline().strip().split(',')
    
    data = np.loadtxt(csv_path, delimiter = ',', skiprows = 1, dtype = "U10, float, float, float, float")
    
    return headers, data

# %%
h, dow = load_csv("DOW.csv")
dow = np.flip(d, axis = 0)
h, sp = load_csv("SP.csv")
dow = np.flip(d, axis = 0)
h, nas = load_csv("NASDAQ.csv")
dow = np.flip(d, axis = 0)

# %%
def process_stocks(data):
    monthly = []
    i = 0
    
    while (i < data.shape[0]):
        chunk = data[i:i + 30]
        month = chunk[0][0][:2]
        year = chunk[0][0][-2:]
        
        avgs = [(op + cl)/2 for (date, op, high, low, cl) in chunk if date[:2] == month]
        i += len(avgs)
        monthly.append([month + "-" + year, np.mean(avgs)])
        
    return monthly

# %%
with open('NASDAQ_processed.csv', 'w') as csvfile:
    csvwriter = csv.writer(csvfile, delimiter=',')
    csvwriter.writerows(process_stocks(nas))

# %%
with open('NASDAQ_processed.csv', 'r', newline='') as csv_fh:
    headers = csv_fh.readline().strip().split(',')
    
    data = np.loadtxt('NASDAQ_processed.csv', delimiter = ',', dtype = "U5, float")

data = np.flip(data, axis = 0)
data[0]
# Out:
# ('01-87', 384.22714286)

# %% [markdown]
# # Case Shiller

# %%
city = ["atlanta", "boston", "chicago", "cleveland", "dallas", "denver", "detroit", "la", "miami", \
        "minneapolis", "nyc", "phoenix", "portland", "sf", "seattle", "tampa", "dc"]

dates = ["01-91", "01-90", "01-90", "01-90", "01-00", "01-90", "01-91", "01-90", "01-90", "01-90", "01-87", \
        "01-02", "01-90", "01-90", "01-90", "01-90", "01-96"]

# %%
def load_case(cities, starts):
    data = np.loadtxt(cities, delimiter = ',', skiprows = 1, dtype = "U10, float")
    
    for i in range(len(data)):
        data[i][0] = data[i][0][5:7] + "-" + data[i][0][2:4]
        
    ind = 0
    while (data[ind][0] != starts):
        ind += 1
        
    print(ind)
    print(data[ind])
    
    return data

# %%
x = load_case("Case Shiller/phoenix_case_shiller.csv", "01-91")
    
x
# Out:
# 24
# ('01-91', 65.257142)
# array([('01-89',  67.544051  ), ('02-89',  67.429334  ),
#        ('03-89',  67.710508  ), ('04-89',  67.654028  ),
#        ('05-89',  67.898129  ), ('06-89',  67.662353  ),
#        ('07-89',  67.564226  ), ('08-89',  67.281344  ),
#        ('09-89',  67.139092  ), ('10-89',  66.683583  ),
#        ('11-89',  66.520181  ), ('12-89',  66.406523  ),
#        ('01-90',  66.555729  ), ('02-90',  66.512385  ),
#        ('03-90',  66.439618  ), ('04-90',  66.477806  ),
#        ('05-90',  66.436411  ), ('06-90',  66.562718  ),
#        ('07-90',  66.605385  ), ('08-90',  66.579893  ),
#        ('09-90',  66.253478  ), ('10-90',  65.930643  ),
#        ('11-90',  65.410362  ), ('12-90',  65.356325  ),
#        ('01-91',  65.257142  ), ('02-91',  65.29429   ),
#        ('03-91',  64.604391  ), ('04-91',  64.353381  ),
#        ('05-91',  64.373153  ), ('06-91',  64.879231  ),
#        ('07-91',  65.504723  ), ('08-91',  65.866752  ),
#        ('09-91',  66.044162  ), ('10-91',  65.842451  ),
#        ('11-91',  66.103857  ), ('12-91',  65.950079  ),
#        ('01-92',  66.012555  ), ('02-92',  65.879494  ),
#        ('03-92',  65.934624  ), ('04-92',  65.828348  ),
#        ('05-92',  66.021501  ), ('06-92',  66.079754  ),
#        ('07-92',  66.263952  ), ('08-92',  66.456569  ),
#        ('09-92',  66.540515  ), ('10-92',  66.551108  ),
#        ('11-92',  66.520612  ), ('12-92',  66.5863    ),
#        ('01-93',  66.834786  ), ('02-93',  66.829735  ),
#        ('03-93',  67.20588   ), ('04-93',  67.304484  ),
#        ('05-93',  67.749887  ), ('06-93',  67.947794  ),
#        ('07-93',  68.441292  ), ('08-93',  68.718188  ),
#        ('09-93',  69.284953  ), ('10-93',  69.409256  ),
#        ('11-93',  69.810979  ), ('12-93',  70.025908  ),
#        ('01-94',  70.534334  ), ('02-94',  70.816552  ),
#        ('03-94',  71.279202  ), ('04-94',  71.734317  ),
#        ('05-94',  72.140506  ), ('06-94',  72.469784  ),
#        ('07-94',  72.995963  ), ('08-94',  73.528968  ),
#        ('09-94',  74.055319  ), ('10-94',  74.262788  ),
#        ('11-94',  74.463211  ), ('12-94',  74.786949  ),
#        ('01-95',  75.107261  ), ('02-95',  75.368909  ),
#        ('03-95',  75.519772  ), ('04-95',  75.797825  ),
#        ('05-95',  76.16473   ), ('06-95',  76.820426  ),
#        ('07-95',  77.259401  ), ('08-95',  77.706094  ),
#        ('09-95',  77.865741  ), ('10-95',  78.148717  ),
#        ('11-95',  78.39275   ), ('12-95',  78.735093  ),
#        ('01-96',  79.100816  ), ('02-96',  79.466636  ),
#        ('03-96',  79.925018  ), ('04-96',  80.388214  ),
#        ('05-96',  80.73485   ), ('06-96',  81.103544  ),
#        ('07-96',  81.453217  ), ('08-96',  81.872182  ),
#        ('09-96',  82.096251  ), ('10-96',  82.207017  ),
#        ('11-96',  82.300694  ), ('12-96',  82.338646  ),
#        ('01-97',  82.586181  ), ('02-97',  82.896056  ),
#        ('03-97',  83.388608  ), ('04-97',  83.880945  ),
#        ('05-97',  84.258546  ), ('06-97',  84.519727  ),
#        ('07-97',  84.562373  ), ('08-97',  84.835744  ),
#        ('09-97',  85.256383  ), ('10-97',  85.808816  ),
#        ('11-97',  86.172151  ), ('12-97',  86.409202  ),
#        ('01-98',  86.640946  ), ('02-98',  87.090612  ),
#        ('03-98',  87.516556  ), ('04-98',  88.062038  ),
#        ('05-98',  88.599512  ), ('06-98',  89.410885  ),
#        ('07-98',  90.048436  ), ('08-98',  90.539413  ),
#        ('09-98',  90.860559  ), ('10-98',  91.151557  ),
#        ('11-98',  91.594959  ), ('12-98',  92.042279  ),
#        ('01-99',  92.405315  ), ('02-99',  92.913116  ),
#        ('03-99',  93.807238  ), ('04-99',  94.631384  ),
#        ('05-99',  95.136257  ), ('06-99',  95.768032  ),
#        ('07-99',  96.333568  ), ('08-99',  97.230605  ),
#        ('09-99',  97.90688   ), ('10-99',  98.560888  ),
#        ('11-99',  99.034724  ), ('12-99',  99.485184  ),
#        ('01-00', 100.        ), ('02-00', 100.4262    ),
#        ('03-00', 101.42142   ), ('04-00', 102.12527   ),
#        ('05-00', 102.97905   ), ('06-00', 103.88864   ),
#        ('07-00', 104.34644   ), ('08-00', 104.91929   ),
#        ('09-00', 105.33906   ), ('10-00', 105.67377   ),
#        ('11-00', 105.92548   ), ('12-00', 105.878     ),
#        ('01-01', 105.92923   ), ('02-01', 106.27014   ),
#        ('03-01', 107.04727   ), ('04-01', 107.85289   ),
#        ('05-01', 108.64644   ), ('06-01', 109.19178   ),
#        ('07-01', 109.84973   ), ('08-01', 110.36138   ),
#        ('09-01', 110.75242   ), ('10-01', 111.20141   ),
#        ('11-01', 111.31471   ), ('12-01', 111.56955   ),
#        ('01-02', 111.61452   ), ('02-02', 112.05215   ),
#        ('03-02', 112.63214   ), ('04-02', 113.34157   ),
#        ('05-02', 114.04562   ), ('06-02', 114.82586   ),
#        ('07-02', 115.40782   ), ('08-02', 115.90325   ),
#        ('09-02', 116.14118   ), ('10-02', 116.4198    ),
#        ('11-02', 116.59031   ), ('12-02', 116.70184   ),
#        ('01-03', 117.10013   ), ('02-03', 117.71689   ),
#        ('03-03', 118.74962   ), ('04-03', 119.37305   ),
#        ('05-03', 119.99813   ), ('06-03', 120.79071   ),
#        ('07-03', 121.78535   ), ('08-03', 122.88731   ),
#        ('09-03', 123.81856   ), ('10-03', 124.74643   ),
#        ('11-03', 125.52541   ), ('12-03', 126.3261    ),
#        ('01-04', 126.60891   ), ('02-04', 127.27726   ),
#        ('03-04', 128.49839   ), ('04-04', 130.09813   ),
#        ('05-04', 131.95381   ), ('06-04', 134.00164   ),
#        ('07-04', 136.42104   ), ('08-04', 138.66432   ),
#        ('09-04', 141.64087   ), ('10-04', 145.06704   ),
#        ('11-04', 148.5944    ), ('12-04', 152.37747   ),
#        ('01-05', 155.49277   ), ('02-05', 160.00178   ),
#        ('03-05', 165.96431   ), ('04-05', 173.08342   ),
#        ('05-05', 180.16373   ), ('06-05', 188.95775   ),
#        ('07-05', 197.14783   ), ('08-05', 204.93588   ),
#        ('09-05', 211.45412   ), ('10-05', 215.94855   ),
#        ('11-05', 219.12463   ), ('12-05', 220.74984   ),
#        ('01-06', 221.80593   ), ('02-06', 222.65251   ),
#        ('03-06', 223.53471   ), ('04-06', 225.11916   ),
#        ('05-06', 226.50947   ), ('06-06', 227.41919   ),
#        ('07-06', 227.38094   ), ('08-06', 227.00792   ),
#        ('09-06', 225.19736   ), ('10-06', 224.49635   ),
#        ('11-06', 223.13441   ), ('12-06', 221.50064   ),
#        ('01-07', 220.20203   ), ('02-07', 218.0681    ),
#        ('03-07', 216.8646    ), ('04-07', 215.04072   ),
#        ('05-07', 213.9389    ), ('06-07', 212.51566   ),
#        ('07-07', 210.77614   ), ('08-07', 208.86063   ),
#        ('09-07', 205.27674   ), ('10-07', 200.72116   ),
#        ('11-07', 194.44686   ), ('12-07', 187.67234   ),
#        ('01-08', 180.06204   ), ('02-08', 172.72258   ),
#        ('03-08', 166.96698   ), ('04-08', 161.32732   ),
#        ('05-08', 157.32033   ), ('06-08', 153.18738   ),
#        ('07-08', 149.09424   ), ('08-08', 144.83239   ),
#        ('09-08', 139.79402   ), ('10-08', 135.1846    ),
#        ('11-08', 130.53973   ), ('12-08', 123.93068   ),
#        ('01-09', 117.13355   ), ('02-09', 111.95129   ),
#        ('03-09', 106.92147   ), ('04-09', 104.45183   ),
#        ('05-09', 103.5574    ), ('06-09', 104.73399   ),
#        ('07-09', 106.66069   ), ('08-09', 108.41092   ),
#        ('09-09', 109.26388   ), ('10-09', 110.70864   ),
#        ('11-09', 111.9632    ), ('12-09', 112.47654   ),
#        ('01-10', 111.76485   ), ('02-10', 110.11247   ),
#        ('03-10', 109.51989   ), ('04-10', 110.06003   ),
#        ('05-10', 111.00026   ), ('06-10', 110.98083   ),
#        ('07-10', 110.30218   ), ('08-10', 108.84211   ),
#        ('09-10', 107.15868   ), ('10-10', 105.97354   ),
#        ('11-10', 104.84861   ), ('12-10', 103.10382   ),
#        ('01-11', 101.53842   ), ('02-11', 100.8131    ),
#        ('03-11', 100.27059   ), ('04-11', 100.36054   ),
#        ('05-11', 100.39997   ), ('06-11', 100.68585   ),
#        ('07-11', 100.54022   ), ('08-11', 100.42685   ),
#        ('09-11', 100.22416   ), ('10-11', 100.53651   ),
#        ('11-11', 101.12044   ), ('12-11', 101.91071   ),
#        ('01-12', 102.83891   ), ('02-12', 104.11772   ),
#        ('03-12', 106.38024   ), ('04-12', 109.01014   ),
#        ('05-12', 111.91893   ), ('06-12', 114.68202   ),
#        ('07-12', 117.21899   ), ('08-12', 119.2763    ),
#        ('09-12', 120.6493    ), ('10-12', 122.3898    ),
#        ('11-12', 124.15623   ), ('12-12', 125.32666   ),
#        ('01-13', 126.69267   ), ('02-13', 128.1002    ),
#        ('03-13', 130.2859    ), ('04-13', 132.46514   ),
#        ('05-13', 134.96545   ), ('06-13', 137.35564   ),
#        ('07-13', 139.36468   ), ('08-13', 141.46975   ),
#        ('09-13', 143.1364    ), ('10-13', 144.49399   ),
#        ('11-13', 144.8553    ), ('12-13', 144.47524   ),
#        ('01-14', 144.17831   ), ('02-14', 144.09769   ),
#        ('03-14', 144.72202177), ('04-14', 145.3785517 ),
#        ('05-14', 145.9655717 ), ('06-14', 146.83700262),
#        ('07-14', 147.25281385), ('08-14', 147.57913231),
#        ('09-14', 147.41927889), ('10-14', 147.55822477),
#        ('11-14', 147.75519577), ('12-14', 147.90057759),
#        ('01-15', 147.84611258), ('02-15', 148.26676925),
#        ('03-15', 149.23128078), ('04-15', 150.45769596),
#        ('05-15', 151.51362364), ('06-15', 152.88107453),
#        ('07-15', 153.95410922), ('08-15', 154.82125876),
#        ('09-15', 155.09662609), ('10-15', 155.89297112),
#        ('11-15', 156.34045343), ('12-15', 157.11936781),
#        ('01-16', 156.70870718), ('02-16', 157.14259635),
#        ('03-16', 157.54347362), ('04-16', 158.64988084),
#        ('05-16', 159.51872259), ('06-16', 160.65078107),
#        ('07-16', 161.90823854), ('08-16', 162.7988663 ),
#        ('09-16', 163.26403817), ('10-16', 163.84040559),
#        ('11-16', 164.3184031 ), ('12-16', 164.57110595),
#        ('01-17', 164.72508751), ('02-17', 165.31441002),
#        ('03-17', 166.22183038), ('04-17', 167.61971325),
#        ('05-17', 168.64728029), ('06-17', 169.89355809),
#        ('07-17', 170.81855706), ('08-17', 172.10830516),
#        ('09-17', 173.12972291), ('10-17', 173.55023163),
#        ('11-17', 173.43246145), ('12-17', 173.71285916),
#        ('01-18', 174.20622524), ('02-18', 175.7380236 ),
#        ('03-18', 177.45230288), ('04-18', 179.00157813),
#        ('05-18', 180.75587855), ('06-18', 182.15011809),
#        ('07-18', 183.48048839), ('08-18', 184.17842652),
#        ('09-18', 185.46203459), ('10-18', 186.75932826),
#        ('11-18', 187.35443941), ('12-18', 187.41904842),
#        ('01-19', 187.21234954), ('02-19', 187.49806429),
#        ('03-19', 188.29752557), ('04-19', 189.7186    ),
#        ('05-19', 191.07809844), ('06-19', 192.63293117),
#        ('07-19', 193.99868985), ('08-19', 195.75110388),
#        ('09-19', 196.6239311 ), ('10-19', 197.66498955),
#        ('11-19', 198.32383124), ('12-19', 199.52651854),
#        ('01-20', 200.14265744), ('02-20', 201.52992472),
#        ('03-20', 203.65980254), ('04-20', 206.4734058 ),
#        ('05-20', 208.28201403), ('06-20', 210.00431048),
#        ('07-20', 211.83405742), ('08-20', 215.08668196),
#        ('09-20', 219.15159341), ('10-20', 222.81087461),
#        ('11-20', 225.62648448), ('12-20', 228.23864118),
#        ('01-21', 231.87910468), ('02-21', 236.58191329),
#        ('03-21', 244.54040721), ('04-21', 252.65091307),
#        ('05-21', 262.09472978), ('06-21', 271.45091238),
#        ('07-21', 280.45597598), ('08-21', 286.70849446),
#        ('09-21', 291.54545899), ('10-21', 294.82592634),
#        ('11-21', 298.30496442), ('12-21', 302.31341351),
#        ('01-22', 307.44163176), ('02-22', 314.31638294)],
#       dtype=[('f0', '<U10'), ('f1', '<f8')])

# %%
x[1][0]
# Out:
# '1991-02-01'
